# %% [markdown]
# ![Screenshot%202023-09-25%20at%203.41.20%20PM.png](attachment:Screenshot%202023-09-25%20at%203.41.20%20PM.png)

# %%
#Import the necessary library.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import load_boston
